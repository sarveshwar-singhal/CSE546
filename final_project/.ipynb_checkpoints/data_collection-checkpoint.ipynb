# %%
from yahoofinancials import YahooFinancials

# %%
import yfinance as yf

# %%
import tqdm
import time

# %%
import numpy as np
import pandas as pd

# %%
aapl_obj = YahooFinancials('AAPL')

# %%
aapl = aapl_obj.get_historical_price_data(start_date='1970-01-01', end_date='2022-04-16', time_interval='daily')

# %%
aapl
# Out:
# {'AAPL': {'eventsData': {'dividends': {'1987-05-11': {'amount': 0.000536,
#      'date': 547738200,
#      'formatted_date': '1987-05-11'},
#     '1987-08-10': {'amount': 0.000536,
#      'date': 555600600,
#      'formatted_date': '1987-08-10'},
#     '1987-11-17': {'amount': 0.000714,
#      'date': 564157800,
#      'formatted_date': '1987-11-17'},
#     '1988-02-12': {'amount': 0.000714,
#      'date': 571674600,
#      'formatted_date': '1988-02-12'},
#     '1988-05-16': {'amount': 0.000714,
#      'date': 579792600,
#      'formatted_date': '1988-05-16'},
#     '1988-08-15': {'amount': 0.000714,
#      'date': 587655000,
#      'formatted_date': '1988-08-15'},
#     '1988-11-21': {'amount': 0.000893,
#      'date': 596125800,
#      'formatted_date': '1988-11-21'},
#     '1989-02-17': {'amount': 0.000893,
#      'date': 603729000,
#      'formatted_date': '1989-02-17'},
#     '1989-05-22': {'amount': 0.000893,
#      'date': 611847000,
#      'formatted_date': '1989-05-22'},
# ...

# %%
aapl_df = pd.DataFrame(aapl['AAPL']['prices'])

# %%
aapl_df
# Out:
#              date        high         low        open       close     volume  \
# 0       345479400    0.128906    0.128348    0.128348    0.128348  469033600
# 1       345738600    0.122210    0.121652    0.122210    0.121652  175884800
# 2       345825000    0.113281    0.112723    0.113281    0.112723  105728000
# 3       345911400    0.116071    0.115513    0.115513    0.115513   86441600
# 4       345997800    0.119420    0.118862    0.118862    0.118862   73449600
# ...           ...         ...         ...         ...         ...        ...
# 10419  1649424600  171.779999  169.199997  171.779999  170.089996   76515900
# 10420  1649683800  169.029999  165.500000  168.710007  165.750000   72246700
# 10421  1649770200  169.869995  166.639999  168.020004  167.660004   79265200
# 10422  1649856600  171.039993  166.770004  167.389999  170.399994   70618900
# 10423  1649943000  171.270004  165.039993  170.619995  165.289993   75237500
#
#          adjclose formatted_date
# ...

# %%
aapl_df.to_excel(excel_writer="file1.xlsx", sheet_name="sheet1", index=False)

# %%
# yahoo_financials = YahooFinancials('AAPL')
# data = yahoo_financials.get_historical_price_data(start_date='2019-01-01', 
#                                                   end_date='2021-12-31', 
#                                                   time_interval='daily')
# aapl_df = pd.DataFrame(data['AAPL']['prices'])
# aapl_df = aapl_df.drop('date', axis=1).set_index('formatted_date')
# aapl_df.head()

# %%
aapl_df

# %%
msft = yf.download('MSFT', 
                      start='2019-01-01', 
                      end='2021-06-12', 
                      progress=False,
)
msft.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  38.277527  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.464802  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.936081  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.856094  219111200
# 2019-01-08  37.389999  37.955002  37.130001  37.687500  36.539616  164101200

# %%
msft_df= yf.download('MSFT', start='1970-01-01',end='2022-04-16', progress=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
msft_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061252
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063439
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064533
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062892
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061799
# ...                ...         ...         ...         ...         ...
# 2022-04-08  300.440002  301.119995  296.279999  296.970001  296.970001
# 2022-04-11  291.790009  292.609985  285.000000  285.260010  285.260010
# 2022-04-12  289.239990  290.739990  280.489990  282.059998  282.059998
# 2022-04-13  282.730011  288.579987  281.299988  287.619995  287.619995
# 2022-04-14  288.089996  288.309998  279.320007  279.829987  279.829987
#
#                 Volume
# Date
# 1986-03-13  1031788800
# 1986-03-14   308160000
# 1986-03-17   133171200
# ...

# %%
msft_df.to_excel('microsoft_all.xlsx', sheet_name='sheet 1', index=True)
